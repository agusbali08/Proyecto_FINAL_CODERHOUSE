# %% [markdown]
# # **Presentación del proyecto**

# %% [markdown]
# **Abstracto con Motivación y Audiencia**

# %% [markdown]
# Abstracto:
#
# El proyecto tiene como objetivo analizar un conjunto de datos relacionados con el mercado de vehiculos en EAU, abordando distintos factores que pueden tener relevancia en el precio de los vehiculos como la marca, el modelo, el año, el kilometraje, el estado del vehículo y la ubicación. Se desarrollara un modelo de regresión lineal para predecir el precio de venta de los vehículos en EAU.
#
# Motivacion:
#
# Predecir el precio de venta de un vehículo es una tarea crucial para compradores, vendedores y comerciantes de vehículos. Los compradores necesitan estimar el valor real de un vehículo para tomar una decisión de compra informada. Los vendedores necesitan establecer un precio competitivo para maximizar sus ganancias. Los comerciantes de vehículos necesitan predecir los precios de compra y venta para gestionar sus inventarios y optimizar sus beneficios.
#
# Audencia:
#
# Este estudio está dirigido a una amplia audiencia, incluyendo:
#
# -Compradores de vehículos: El modelo puede ayudar a los compradores a obtener una estimación precisa del valor de un vehículo antes de realizar una compra.
#
# -Vendedores de vehículos: El modelo puede ayudar a los vendedores a establecer un precio competitivo para sus vehículos y maximizar sus ganancias.
#
# -Comerciantes de vehículos: El modelo puede ayudar a los comerciantes de vehículos a predecir los precios de compra y venta, gestionar sus inventarios y optimizar sus beneficios.
#
# -Analistas de mercado: El modelo puede ser utilizado por analistas de mercado para estudiar las tendencias del mercado, identificar factores que influyen en los precios de los vehículos y realizar pronósticos futuros.

# %% [markdown]
# **Contexto Comercial y Analítico**

# %% [markdown]
# Contexto comercial:
#
# El mercado automotriz de EAU tiene una gran importancia en el sector automotriz en general, por esta razon es muy importante hacer una eficiente prediccion de los precios futuros ya que estos marcan un parametro para los otros paises.
#
# Problema comercial:
#
# El problema central es poder mejorar la eficiencia de la prediccion de los precios futuros de los autos para que esto ayude tanto a los compradores como venderes a sacar la mayor ganancia posible.
#
# Contexto Analítico: El enfoque analítico se basará en técnicas de análisis exploratorio de datos (EDA) para revelar patrones, correlaciones y tendencias en el conjunto de datos. Se utilizarán visualizaciones y resúmenes numéricos para facilitar la interpretación de los resultados.
#
# Exploración de Datos (EDA): El DataFrame proporcionado tiene 9953 entradas y 27 columnas. Las variables incluyen información sobre el precio, marca, modelo, año, kilometraje, estado del vehículo, tipo de cuerpo, tipo de combustible, capacidad del motor, caballos de fuerza, color exterior, color interior, número de puertas, número de asientos, garantía.

# %% [markdown]
# **Preguntas/Hipótesis a Resolver mediante el Análisis de Datos**

# %% [markdown]
# ¿Qué factores influyen más en el precio de venta de un vehículo en los EAU? (Marca, modelo, año, kilometraje, estado, ubicación, etc.)
#
# ¿Existen patrones de precios específicos para diferentes marcas, modelos o años de vehículos?
#
# ¿Hay una gran diferencia entre la prediccion de vehiculos nuevos con vehiculos usados?

# %% [markdown]
# **Objetivo**

# %% [markdown]
# Desarrollar un modelo de aprendizaje automático preciso y confiable para predecir el precio de venta de vehículos nuevos y usados en los Emiratos Árabes Unidos (EAU), utilizando un conjunto de datos y técnicas de análisis exploratorio de datos (EDA) y regresión lineal.

# %% [markdown]
# # **Lectura de datos**

# %% [markdown]
# **Librerias necesarias para el analisis de datos**

# %%
# Importamos las librerias
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %% [markdown]
# **Configuración del entorno de Python en Google Colab**

# %%
# Montar Google drive
from google.colab import drive
import os
drive.mount("/content/drive")
print(os.getcwd())
os.chdir("/content/drive/My Drive/DesafiosD552295")
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/DesafiosD552295
# /content/drive/My Drive/DesafiosD552295

# %% [markdown]
# **Lectura del dataset**

# %%
# Cargar el dataset
df = pd.read_csv('/content/drive/MyDrive/DesafiosD552295/Dataset/mercado_autos.csv', encoding='utf-8')

# %% [markdown]
# **Análisis inicial del dataset**

# %%
df.head()
# Out:
#     price       brand      model           trim  kilometers  year  \
# 0  129900       Dodge        Ram  1500 SLT Crew       47566  2021
# 1  319900  Alfa Romeo    Stelvio   Quadrifoglio        8914  2020
# 2  149900        Audi         Q5         S-line       72205  2019
# 3   79900  Alfa Romeo  GIULIETTA         Veloce       49193  2021
# 4  154900         GAC        GS8             GL          30  2024
#
#    vehicle_age_years regional_specs  doors      body_type  ... interior_color  \
# 0                  3      GCC Specs      4  Pick Up Truck  ...        Unknown
# 1                  4      GCC Specs      5            SUV  ...          Black
# 2                  5      GCC Specs      5            SUV  ...          Brown
# 3                  3      GCC Specs      4      Hatchback  ...          Black
# 4                  0      GCC Specs      5            SUV  ...    Other Color
#
#    warranty                         address country   city  area_name  \
# ...

# %%
df.shape
# Out:
# (9953, 27)

# %%
df.sample(7)
# Out:
#        price       brand        model           trim  kilometers  year  \
# 2156   11000       Honda        Other          Other      252271  1991
# 927   315000      Nissan       Patrol          Nismo       68162  2022
# 6466  849000  Land Rover  Range Rover  Autobiography           0  2023
# 7659   30000  Volkswagen      Touareg             SE      157000  2012
# 3287   41000     Hyundai       Accent             GL       65658  2020
# 9346  400000  Land Rover     Defender          Other           0  2023
# 8500   32000      Nissan         Juke          Other      133000  2014
#
#       vehicle_age_years regional_specs  doors body_type  ... interior_color  \
# 2156                 33      GCC Specs      2     Coupe  ...          Beige
# 927                   2      GCC Specs      5       SUV  ...        Unknown
# 6466                  1          Other      4       SUV  ...    Other Color
# 7659                 12      GCC Specs      5       SUV  ...        Unknown
# ...

# %%
df.tail()
# Out:
#        price    brand         model      trim  kilometers  year  \
# 9948  215000    Lexus         LX570  Platinum      191000  2016
# 9949   78000  Porsche       Cayenne       GTS      165000  2014
# 9950  173000   Toyota  Land Cruiser       GXR      134000  2018
# 9951   63000   Toyota         Prado  Tx-l MID      290000  2011
# 9952   90000   Nissan        Patrol        SE      166000  2017
#
#       vehicle_age_years regional_specs  doors body_type  ... interior_color  \
# 9948                  8      GCC Specs      4       SUV  ...          Beige
# 9949                 10      GCC Specs      4       SUV  ...        Unknown
# 9950                  6      GCC Specs      4       SUV  ...          Beige
# 9951                 13      GCC Specs      5       SUV  ...          Beige
# 9952                  7      GCC Specs      4       SUV  ...        Unknown
#
#             warranty                                            address  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9953 entries, 0 to 9952
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price               9953 non-null   int64
#  1   brand               9953 non-null   object
#  2   model               9953 non-null   object
#  3   trim                9941 non-null   object
#  4   kilometers          9953 non-null   int64
#  5   year                9953 non-null   int64
#  6   vehicle_age_years   9953 non-null   int64
#  7   regional_specs      9953 non-null   object
#  8   doors               9953 non-null   int64
#  9   body_type           9953 non-null   object
#  10  fuel_type           9953 non-null   object
#  11  seating_capacity    9953 non-null   int64
#  12  transmission_type   9953 non-null   object
#  13  engine_capacity_cc  7992 non-null   object
#  14  horsepower          9495 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['price', 'brand', 'model', 'trim', 'kilometers', 'year',
#        'vehicle_age_years', 'regional_specs', 'doors', 'body_type',
#        'fuel_type', 'seating_capacity', 'transmission_type',
#        'engine_capacity_cc', 'horsepower', 'no_of_cylinders', 'exterior_color',
#        'interior_color', 'warranty', 'address', 'country', 'city', 'area_name',
#        'location_name', 'latitude', 'longitude', 'seller_type'],
#       dtype='object')

# %%
df.dtypes.value_counts()
# Out:
# object     18
# int64       7
# float64     2
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                price    kilometers         year  vehicle_age_years  \
# count    9953.000000  9.953000e+03  9953.000000        9953.000000
# mean   162009.236311  8.187313e+04  2018.118155           5.881845
# std    187120.064955  9.029117e+04     5.163806           5.163806
# min      1000.000000  0.000000e+00  1956.000000           0.000000
# 25%     44900.000000  1.894100e+04  2016.000000           2.000000
# 50%     92000.000000  6.800000e+04  2019.000000           5.000000
# 75%    205000.000000  1.225000e+05  2022.000000           8.000000
# max    999900.000000  2.580000e+06  2024.000000          68.000000
#
#              doors  seating_capacity  no_of_cylinders     latitude  \
# count  9953.000000       9953.000000      9953.000000  9580.000000
# mean      3.964533          4.597408         5.751432    25.117984
# std       0.948349          1.795174         2.195505     0.220519
# min       2.000000          0.000000         0.000000    23.651535
# ...

# %%
df.describe(include=['object']).T
# Out:
#                    count unique  \
# brand               9953     89
# model               9953    634
# trim                9941    813
# regional_specs      9953      8
# body_type           9953     13
# fuel_type           9953      4
# transmission_type   9953      2
# engine_capacity_cc  7992     10
# horsepower          9495     11
# exterior_color      9953     17
# interior_color      9953     10
# warranty            9953      3
# address             9953    511
# country             9953      1
# city                9953      8
# area_name           9334    241
# location_name       4633    226
# seller_type         9953      3
#
#                                                                   top  freq
# brand                                                   Mercedes-Benz  1531
# model                                                     Range Rover   254
# trim                                                            Other  1949
# ...

# %% [markdown]
# **Descripción de variables**

# %% [markdown]
# Precio: El precio de venta de cada vehículo.
#
# Marca: Fabricante del vehículo.
#
# Modelo: Modelo específico del vehículo.
#
# Recorte: Recortar el nivel del vehículo, indicando diferentes características o paquetes.
#
# Kilómetros: Kilometraje del vehículo, indicando cuánto se ha utilizado.
#
# Año: Año de fabricación.
#
# Años de Edad del Vehículo: La edad del vehículo calculada a partir del año en curso.
#
# Especificaciones Regionales: Especificaciones adaptadas al CCG u otras regiones.
#
# Puertas: Número de puertas en el vehículo.
#
# Tipo de Cuerpo: Tipo de carrocería del vehículo (por ejemplo, SUV, hatchback).
#
# Tipo de Combustible: Tipo de combustible que utiliza el vehículo (por ejemplo, gasolina, diesel).
#
# Capacidad de Asientos: Número de asientos en el vehículo.
#
# Tipo de Transmisión: Transmisión manual o automática.
#
# Capacidad del motor CC: Tamaño del motor en centímetros cúbicos.
#
# Caballos: Potencia de salida del motor del vehículo.
#
# No de Cilindros: Número de cilindros del motor.
#
# Color Exterior: Color del exterior del vehículo.
#
# Color Interior: Color del interior del vehículo.
#
# Garantía: Indica si el vehículo viene con una garantía.
#
# Dirección/País/Ciudad/Nombre de Área/Nombre de Ubicación: Información detallada de la ubicación donde se vende el vehículo.
#
# Latitud/Longitud: Coordenadas geográficas del vehículo listado.
#
# Tipo de Vendedor: Indica si el vendedor es un concesionario o un particular.

# %% [markdown]
# # **Data Wrangling: Limpieza y transformación de datos**

# %% [markdown]
# **Valores duplicados**

# %%
duplicados_exactos = df.duplicated().sum()

# Analizar duplicados en detalle
duplicados = df[df.duplicated()]
print(duplicados)  # Examinar las filas duplicadas
# Out:
#        price          brand       model         trim  kilometers  year  \
# 412   109000         Jetour     Dashing  1.6T Luxury          10  2024
# 713   489000  Mercedes-Benz   GLS-Class      GLS 450           0  2024
# 1275   64900        Porsche     Cayenne            S      124177  2011
# 1325  135000  Mercedes-Benz     A-Class     AMG A 35      170000  2020
# 1326  599000  Mercedes-Benz     G-Class     G 63 AMG       82000  2020
# ...      ...            ...         ...          ...         ...   ...
# 9892  335000            BMW          iX        Other         500  2023
# 9893  170000           MINI  Countryman     Cooper S         500  2024
# 9894  450000            BMW          X7  40i M Sport         500  2024
# 9895  285000            BMW          X4   xDrive 30i         500  2024
# 9896  330000            BMW    4-Series         440i         500  2024
#
#       vehicle_age_years  regional_specs  doors             body_type  ...  \
# ...

# %%
# Comparar filas con la anterior usando eq y shift
filas_iguales_anterior = df.eq(df.shift(1)).all(axis=1)

# Comparar filas con df.iloc[0] usando eq
filas_iguales_primera = df.eq(df.iloc[0]).all(axis=1)

# Identificar filas completamente iguales
filas_completamente_iguales = filas_iguales_anterior & filas_iguales_primera

# Mostrar filas completamente iguales
df[filas_completamente_iguales]
# Out:
# Empty DataFrame
# Columns: [price, brand, model, trim, kilometers, year, vehicle_age_years, regional_specs, doors, body_type, fuel_type, seating_capacity, transmission_type, engine_capacity_cc, horsepower, no_of_cylinders, exterior_color, interior_color, warranty, address, country, city, area_name, location_name, latitude, longitude, seller_type]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# Hay valores duplicados ya que algunos autos pueden compartir mismas caracteristicas, pero no hay filas completamente iguales que vayan a afectar la predccion de nuestro modelos, todas las filas son relevnates. Por eso no se van a borrar.

# %% [markdown]
# **Valores nulos**

# %%
df.isnull().sum()
# Out:
# price                    0
# brand                    0
# model                    0
# trim                    12
# kilometers               0
# year                     0
# vehicle_age_years        0
# regional_specs           0
# doors                    0
# body_type                0
# fuel_type                0
# seating_capacity         0
# transmission_type        0
# engine_capacity_cc    1961
# horsepower             458
# no_of_cylinders          0
# exterior_color           0
# interior_color           0
# warranty                 0
# address                  0
# country                  0
# city                     0
# area_name              619
# location_name         5320
# latitude               373
# longitude              373
# seller_type              0
# dtype: int64

# %% [markdown]
# Se eliminna las colummnas que tiene vaolres nulos y no son relevantes ya que la informacion esta en la columna address

# %%
#vamos a eliminar las columnas location_name, longuitude, latitude, area_name.

columnas_a_eliminar = ['area_name', 'location_name', 'latitude', 'longitude']
df_reduced = df.drop(columnas_a_eliminar, axis=1, inplace=False)

#confirmamos que se hayan borrado correctamente

df_reduced.head()
# Out:
#     price       brand      model           trim  kilometers  year  \
# 0  129900       Dodge        Ram  1500 SLT Crew       47566  2021
# 1  319900  Alfa Romeo    Stelvio   Quadrifoglio        8914  2020
# 2  149900        Audi         Q5         S-line       72205  2019
# 3   79900  Alfa Romeo  GIULIETTA         Veloce       49193  2021
# 4  154900         GAC        GS8             GL          30  2024
#
#    vehicle_age_years regional_specs  doors      body_type  ...  \
# 0                  3      GCC Specs      4  Pick Up Truck  ...
# 1                  4      GCC Specs      5            SUV  ...
# 2                  5      GCC Specs      5            SUV  ...
# 3                  3      GCC Specs      4      Hatchback  ...
# 4                  0      GCC Specs      5            SUV  ...
#
#   engine_capacity_cc    horsepower no_of_cylinders exterior_color  \
# 0           4000+ cc  300 - 399 HP               8          White
# ...

# %%
#ponemos other donde hay valores nulos en la columna trim

df_reduced['trim'].fillna('Other', inplace=True)

#vemos que no haya valores nulos en la columna trim

df_reduced.isnull().sum()
# Out:
# price                    0
# brand                    0
# model                    0
# trim                     0
# kilometers               0
# year                     0
# vehicle_age_years        0
# regional_specs           0
# doors                    0
# body_type                0
# fuel_type                0
# seating_capacity         0
# transmission_type        0
# engine_capacity_cc    1961
# horsepower             458
# no_of_cylinders          0
# exterior_color           0
# interior_color           0
# warranty                 0
# address                  0
# country                  0
# city                     0
# seller_type              0
# dtype: int64

# %%
#eliminamos los registros con valores nulos

df_reduced.dropna(inplace=True)

#confirmamos que se hayan eliminado correctamente

df_reduced.isnull().sum()
# Out:
# price                 0
# brand                 0
# model                 0
# trim                  0
# kilometers            0
# year                  0
# vehicle_age_years     0
# regional_specs        0
# doors                 0
# body_type             0
# fuel_type             0
# seating_capacity      0
# transmission_type     0
# engine_capacity_cc    0
# horsepower            0
# no_of_cylinders       0
# exterior_color        0
# interior_color        0
# warranty              0
# address               0
# country               0
# city                  0
# seller_type           0
# dtype: int64

# %%
#vemos que la nueva dimension del dataframe

df_reduced.shape
# Out:
# (7902, 23)

# %%
df_reduced.dtypes
# Out:
# price                  int64
# brand                 object
# model                 object
# trim                  object
# kilometers             int64
# year                   int64
# vehicle_age_years      int64
# regional_specs        object
# doors                  int64
# body_type             object
# fuel_type             object
# seating_capacity       int64
# transmission_type     object
# engine_capacity_cc    object
# horsepower            object
# no_of_cylinders        int64
# exterior_color        object
# interior_color        object
# warranty              object
# address               object
# country               object
# city                  object
# seller_type           object
# dtype: object

# %% [markdown]
# Voy a pasar a convertir las variables engine_capacity_cc y horsepower en variables numericas

# %%
# elimino el + que hay en algunos en la columa
df_reduced['engine_capacity_cc'] = df_reduced['engine_capacity_cc'].str.replace('+', '')

# %%
# Reemplazo "unknown" por "unknown cc"
df_reduced['engine_capacity_cc'] = df_reduced['engine_capacity_cc'].str.replace('Unknown', 'Unknown cc')
df_reduced['horsepower'] = df_reduced['horsepower'].str.replace('Unknown', 'Unknown HP')

# %%
# Separo la columna con los valores reemplazados(dejo solo el primer numero como la capacidad del motor para poder analizarlo)
df_reduced[["engine_consumption", "engine_measure", "none_1", "none_2"]] = df_reduced['engine_capacity_cc'].str.split(' ', expand=True)

# %%
# Separo la columna con los valores reemplazados
df_reduced[["horsepower_consumption", "horsepower_measure", "none3", "none4"]] = df_reduced['horsepower'].str.split(' ', expand=True)

# %%
# borrar las columnas "engine_measure", "none_1", "none_2", "horsepower_measure", "none3", "none4" ya que se utilizaron para trasformar las columnas engine_capacity_cc y horsepower en valores numericos

columnas_eliminar =["engine_measure", "none_1", "none_2", "horsepower_measure", "none3", "none4"]

df_clean = df_reduced.drop(columnas_eliminar, axis=1, inplace=False)

# %%
data = df_clean.drop(columns=["engine_capacity_cc", "horsepower"], axis=1, inplace=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7902 entries, 0 to 9949
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   price                   7902 non-null   int64
#  1   brand                   7902 non-null   object
#  2   model                   7902 non-null   object
#  3   trim                    7902 non-null   object
#  4   kilometers              7902 non-null   int64
#  5   year                    7902 non-null   int64
#  6   vehicle_age_years       7902 non-null   int64
#  7   regional_specs          7902 non-null   object
#  8   doors                   7902 non-null   int64
#  9   body_type               7902 non-null   object
#  10  fuel_type               7902 non-null   object
#  11  seating_capacity        7902 non-null   int64
#  12  transmission_type       7902 non-null   object
#  13  no_of_cylinders         7902 non-null   int64
# ...

# %%
data.rename(columns={"engine_consumption": "engine_capacity_cc", "horsepower_consumption": "horsepower_hp"}, inplace=True)

# %%
data.dtypes
# Out:
# price                  int64
# brand                 object
# model                 object
# trim                  object
# kilometers             int64
# year                   int64
# vehicle_age_years      int64
# regional_specs        object
# doors                  int64
# body_type             object
# fuel_type             object
# seating_capacity       int64
# transmission_type     object
# no_of_cylinders        int64
# exterior_color        object
# interior_color        object
# warranty              object
# address               object
# country               object
# city                  object
# seller_type           object
# engine_capacity_cc    object
# horsepower_hp         object
# dtype: object

# %%
cantidad_unknown = data["engine_capacity_cc"].str.lower().value_counts().get("unknown", 0)
cantidad_unknown
# Out:
# 625

# %%
#al no ser una cifra significativa los elimino
data = data.drop(data[data["engine_capacity_cc"].str.strip() == "Unknown"].index)

# %%
#verifico que no queden
print(data["engine_capacity_cc"].value_counts().get("Unknown", 0))
# Out:
# 0

# %%
#veo cuantos valores Unknown hay
cantidad_unknown_horsepower = data["horsepower_hp"].str.lower().value_counts().get("unknown", 0)
cantidad_unknown_horsepower
# Out:
# 256

# %%
#al no ser una cifra significativa los elimino
data = data.drop(data[data["horsepower_hp"].str.strip() == "Unknown"].index)

# %%
#verifico que no queden
print(data["horsepower_hp"].value_counts().get("Unknown", 0))
# Out:
# 0

# %%
#data["engine_capacity_cc"].isna().sum()
data["horsepower_hp"].isna().sum()
# Out:
# 0

# %%
# elimino el + que hay en algunos en la columa
data['horsepower_hp'] = data['horsepower_hp'].str.replace('+', '')

# %%
data["engine_capacity_cc"] = data["engine_capacity_cc"].astype(int)
data["horsepower_hp"] = data["horsepower_hp"].astype(int)

# %% [markdown]
# Borramos las columnas que no son muy relevantes para el analisis

# %%
datos = data.drop(columns=["regional_specs", "trim", "body_type", "country", "body_type", "interior_color", "exterior_color", "doors", "vehicle_age_years", "address"], axis=1, inplace=False)

# %%
datos.dtypes
# Out:
# price                  int64
# brand                 object
# model                 object
# kilometers             int64
# year                   int64
# fuel_type             object
# seating_capacity       int64
# transmission_type     object
# no_of_cylinders        int64
# warranty              object
# city                  object
# seller_type           object
# engine_capacity_cc     int64
# horsepower_hp          int64
# dtype: object

# %% [markdown]
# **Valores outliers**

# %%
numeric_columns = datos.select_dtypes(include=['int64', 'float64'])

# Calcular el número de filas y columnas para los subgráficos
num_vars = len(numeric_columns.columns)
num_rows = (num_vars // 3) + (1 if num_vars % 3 > 0 else 0)
num_cols = min(num_vars, 3)

# Configurar el tamaño de la figura
plt.figure(figsize=(15, 5*num_rows))

# Generar y mostrar los diagramas de caja para cada variable numérica
for i, col in enumerate(numeric_columns.columns):
    plt.subplot(num_rows, num_cols, i+1)
    sns.boxplot(x=datos[col])
    plt.title("Boxplot de {}".format(col))
    plt.tight_layout()

plt.show()

# %% [markdown]
# # **EDA: Análisis Exploratorio de datos**

# %% [markdown]
# Se observa la distribucion de las variables cualitativas

# %%
# Histograma para el tipo de combustible
plt.hist(datos['fuel_type'], bins=40, edgecolor='black')
plt.title('Tipos de combustible')
plt.xlabel('Tipo de combustible')
plt.ylabel('cantidad')
plt.show()

# %%
# Histograma para el tipo de transmision
plt.hist(datos['transmission_type'], bins=10, edgecolor='black')
plt.title('Tipos de transmision')
plt.xlabel('Tipo de transmision')
plt.ylabel('cantidad')
plt.show()

# %%
# Histograma para el tipo de caballos de fuerza
plt.hist(datos['seller_type'], bins=10, edgecolor='black')
plt.title('Tipo de vendedor')
plt.xlabel('Vendedor')
plt.ylabel('cantidad')
plt.show()

# %%
# Histograma para el tipo de marca

# Filtrar las 20 marcas más frecuentes
marcas_top20 = datos["brand"].value_counts().head(20)

# Crear el gráfico de barras
plt.figure(figsize=(20, 8))
plt.bar(marcas_top20.index, marcas_top20.values)
plt.xlabel("Marcas")
plt.ylabel("Cantidad")
plt.title("Top 20 Marcas de Autos")
plt.show()

# %%
# Histograma para el tipo de modelo

# Filtrar los 20 modelos más frecuentes
modelos_top20 = datos["model"].value_counts().head(20)

# Crear el gráfico de barras
plt.figure(figsize=(35, 8))
plt.bar(modelos_top20.index, marcas_top20.values)
plt.xlabel("Modelos")
plt.ylabel("Cantidad")
plt.title("Top 20 Modelos de Autos")
plt.show()

# %%
# Histograma para ver cuantos autos tienen garantia
plt.hist(datos['warranty'], bins=10, edgecolor='black')
plt.title('Garantia')
plt.xlabel('Tiene o no garantia')
plt.ylabel('cantidad')
plt.show()

# %%
# Histograma para ver cuantos autos tienen garantia
plt.figure(figsize=(25, 8))
plt.hist(datos['city'], bins=10, edgecolor='black')
plt.title('Ciudad')
plt.xlabel('Ciudad')
plt.ylabel('cantidad')
plt.show()

# %% [markdown]
# Se observa la distribucion en porcentajes

# %%
print("% combustible:")
print (datos["fuel_type"].value_counts(normalize=True))

print ("---"*15)

print("% vendedor:")
print (datos["seller_type"].value_counts(normalize=True))
print ("---"*15)

print("% transmision:")
print (datos["transmission_type"].value_counts(normalize=True))
print ("---"*15)

print("% marca:")
print (datos["brand"].value_counts(normalize=True))
print ("---"*15)

print("% modelo:")
print (datos["model"].value_counts(normalize=True))
print ("---"*15)

print("% garantia:")
print (datos["warranty"].value_counts(normalize=True))
print ("---"*15)

print("% ciudades:")
print (datos["city"].value_counts(normalize=True))
# Out:
# % combustible:
# fuel_type
# Petrol      0.969520
# Hybrid      0.015240
# Diesel      0.013104
# Electric    0.002136
# Name: proportion, dtype: float64
# ---------------------------------------------
# % vendedor:
# seller_type
# Dealer                            0.637943
# Owner                             0.331577
# Dealership/Certified Pre-Owned    0.030480
# Name: proportion, dtype: float64
# ---------------------------------------------
# % transmision:
# transmission_type
# Automatic Transmission    0.973508
# Manual Transmission       0.026492
# Name: proportion, dtype: float64
# ---------------------------------------------
# % marca:
# brand
# Mercedes-Benz    0.148839
# BMW              0.096567
# Nissan           0.079476
# Toyota           0.072354
# Land Rover       0.066372
#                    ...
# UAZ              0.000142
# Iveco            0.000142
# Daewoo           0.000142
# Great Wall       0.000142
# Exeed            0.000142
# ...

# %% [markdown]
# Se realiza un histograma de las variables numericas. Se observa lo siguiente:
#
# Kilometros recorridos: tiene una distribucion normal acostada sobre la cola derecha.
#
# numero de cilindradas: no tiene una distribucion normal
#
# Engine Consumption: no tiene distribucion normal
#
# Max_power: no tiene distribucion normal

# %%
fig, axes = plt.subplots(1,4,figsize=(25,8))

sns.distplot(datos["kilometers"], hist=True, kde=True, color="g",ax=axes[0] )

sns.distplot(datos["no_of_cylinders"], hist=True, kde=True, color="g", ax=axes[1])

sns.distplot(datos["engine_capacity_cc"], hist=True, kde=True, color="g", ax=axes[2])

sns.distplot(datos["horsepower_hp"], hist=True, kde=True, color="g", ax=axes[3])

plt.show()
# Out:
# <ipython-input-117-a4bb131713be>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(datos["kilometers"], hist=True, kde=True, color="g",ax=axes[0] )
# <ipython-input-117-a4bb131713be>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# Se realiza un analisis con Boxplots. Se observa que todas las variables numericas tienen valores anomalos que deberan ser tratados para evitar distorciones en el modelo

# %%
# boxplot
# aclaracion: el eje x de la figura "kilometers" esta en formato cientifico ya que hay valores muy grandes. Para obtener los valores reales se debe multiplicar por 1000000

fig, axes = plt.subplots(1,4,figsize=(25,8))

plt.subplot(1,4,1)
sns.boxplot(datos["kilometers"])
plt.yticks(np.arange(0,3000000,200000))

plt.subplot(1,4,2)
sns.boxplot(datos["no_of_cylinders"])
plt.yticks(np.arange(0,15,2))

plt.subplot(1,4,3)
sns.boxplot(datos["engine_capacity_cc"])
plt.yticks(np.arange(0,5000,400))

plt.subplot(1,4,4)
sns.boxplot(datos["horsepower_hp"])
plt.yticks(np.arange(50,1000,30))

plt.show()

# %% [markdown]
# e realiza un analisis por separado mi variable target: "price".

# %%
sns.boxplot(datos["price"])
plt.yticks(np.arange(0,1100000,70000))
plt.show()

# %% [markdown]
# Analizo la relacion entre los kilometros recorridos y la variable tipo de combustible. Se observa que los autos con combustible diesel tienen valores mas altos que los demas

# %%
sns.barplot(x= datos["fuel_type"], y = datos["price"])
# Out:
# <Axes: xlabel='fuel_type', ylabel='price'>

# %% [markdown]
# Analizo la variable tipo de dueño. Observo que hay unos pocos autos de Pre-Owned con precios muy altos

# %%
fig, axes = plt.subplots(1,2,figsize=(25,8))

plt.subplot(1,2,1)
sns.countplot(datos["seller_type"])
plt.title("Histograma de la variable 'vendedor'")
plt.ylabel("Vendedor")

plt.subplot(1,2,2)
sns.barplot(x= datos["seller_type"], y = datos["price"])
plt.title("Histograma de la variable 'vendedor' analizandolo por  price")
plt.xlabel("Vendedor")
# Out:
# Text(0.5, 0, 'Vendedor')

# %% [markdown]
# Observo que no es necesario eliminarlos ya que 200 es un numero aceptable para el analsis correcto

# %%
datos["seller_type"].value_counts()
# Out:
# seller_type
# Dealer                            4479
# Owner                             2328
# Dealership/Certified Pre-Owned     214
# Name: count, dtype: int64

# %% [markdown]
# Junto todas las columnas numericas

# %%
columnas_numericas = datos.select_dtypes(include=['number']).columns

datos_numerico = datos[columnas_numericas]

# %% [markdown]
# Observo la correlacion entre las variables numericas. Se observa que el precio de venta tiene su mayor correlacion con los caballos de fuerza del auto.

# %%
plt.subplots(figsize=(8,6))
sns.heatmap(datos_numerico.corr(), annot=True,cmap="YlOrBr")
# Out:
# <Axes: >

# %% [markdown]
# Vuelvo a ver esa relacion entre las variables. Se vuelven a observar los valores extremos ya vistos en el boxplot.

# %%
# aca de vuelve a ver esa relacion entre las variables. Se vuelven a observar los valores extremos ya vistos en el boxplot.
plt.figure(figsize=(35, 15))
sns.scatterplot(x="price", y="horsepower_hp", data=datos)
# Out:
# <Axes: xlabel='price', ylabel='horsepower_hp'>

# %% [markdown]
# Observo lo mismo que en el grafico anterior pero segmentandolo tambien por el tipo de combustible

# %%
sns.scatterplot(x=datos["price"], y=datos["horsepower_hp"], hue=datos["fuel_type"])
# Out:
# <Axes: xlabel='price', ylabel='horsepower_hp'>

# %% [markdown]
# Eliminacion de valores outliers

# %%
# defino una funcion para obtener una lista con outliers

def outliers(df,ft):
    q1 = df[ft].quantile(0.25)
    q3 = df[ft].quantile(0.75)
    IQR = q3 - q1

    lower_bound = q1 - 1.5 * IQR
    upper_bound = q3 + 1.5 * IQR

    ls = df.index[ (df[ft] < lower_bound) | (df[ft] > upper_bound)]
    return ls

# %%
# creo una lista para acumular los outliers de diferentes columnas. Solo lo voy a hacer para las variables que voy a analizar.

index_list = []

for feature in ["engine_capacity_cc",  "horsepower_hp","price" ]:
    index_list.extend(outliers(data,feature))

# %%
# creo una funcion para eliminar los outliers y quedarme con el dataframe final

def remove (df,ls):
    ls = sorted(set(ls))
    df = df.drop(ls)
    return df

# %%
# creo el dataset final, filtrando del dataset que tenia, la lista con los outliers

data_cleaned = remove(data, index_list)

# %%
print ("Se han eliminado", data.shape[0] - data_cleaned.shape[0], " variables")
# Out:
# Se han eliminado 1111  variables

# %% [markdown]
# Observo nuevamente los valores anomalos. Observo que todavia quedan algunos

# %%
fig, axes = plt.subplots(1,3,figsize=(25,8))


plt.subplot(1,3,1)
sns.boxplot(data_cleaned["engine_capacity_cc"])

plt.subplot(1,3,2)
sns.boxplot(data_cleaned["horsepower_hp"])

plt.subplot(1,3,3)
sns.boxplot(data_cleaned["price"])


plt.show()

# %% [markdown]
# # **Preprocesamiento de datos**

# %% [markdown]
# #**Feature Selection**

# %% [markdown]
# Se trabajara con la variable target "price". Las variables predictoras seran "horsepower_hp", "year". En una primera instancia iba a trabajar tambien con la variable engine_capacity_cc como predictora pero al observar que entre horsepower y engine capacity a su vez hay correlacion, se decidio no incluir engine_capacity_cc para no distorcionar el analisis. De esas 2, horsepower_hp es la de mayor correlacion con la variable target por eso elegi quedarme con esa y con year.

# %% [markdown]
# **Selección de variable objetivo y variables independientes**

# %%
x = data_cleaned[["year", "engine_capacity_cc",  "horsepower_hp"]]
y = data_cleaned["price"]

# %% [markdown]
# # **Modelos**

# %% [markdown]
# **Librerias necesarias para implementar los modelos**

# %%
# modelos
from sklearn import linear_model
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn import preprocessing
from sklearn.model_selection import KFold
# metricas
from sklearn import model_selection, metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import math, time, random, datetime

# %% [markdown]
# **División de datos en conjuntos de entrenamiento y prueba**

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y)

# %% [markdown]
# Regresion Linear

# %% [markdown]
# Se trabajara con la variable target "price" .La variable predictora sera "horsepower_hp", "year" y "engine_capacity_cc" ya que se observo en el analisis de correlacion que son las variables que mejor explican el cambio en el precio

# %% [markdown]
# Entrenamiento del modelo

# %%
from sklearn import linear_model

regresion = linear_model.LinearRegression()

modelo = regresion.fit(x_train,y_train)

# %% [markdown]
# Generacion de la prediccion sobre los datos de prueba del modelo

# %%
y_pred_linearregression = modelo.predict(x_test)

# %% [markdown]
# Evaluacion del modelo

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred_linearregression)
# Out:
# 0.37276936371405556

# %%
# raiz cuadrada del error cuadratico medio

from sklearn.metrics import mean_squared_error

mean_squared_error(y_test,y_pred_linearregression , squared=False)
# Out:
# 67233.72581352509

# %%
# error cuadratico medio

mean_squared_error(y_test,y_pred_linearregression)
# Out:
# 4520373886.76827

# %%
# error absoluto medio

from sklearn.metrics import mean_absolute_error

mean_absolute_error(y_test,y_pred_linearregression)
# Out:
# 46489.65577288944

# %% [markdown]
# Arbol de decision

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

arbol_decision = DecisionTreeClassifier(criterion="entropy", max_depth=3)

arbol = arbol_decision.fit(x_train, y_train)

# %% [markdown]
# Generacion de la prediccion

# %%
y_pred_decisiontree = arbol.predict(x_test)

# %% [markdown]
# Evaluacion del modelo

# %%
r2_score(y_test, y_pred_decisiontree)
# Out:
# 0.2763487984732841

# %%
mean_squared_error(y_test,y_pred_decisiontree , squared=False)
# Out:
# 72216.7917883247

# %%
mean_squared_error(y_test,y_pred_decisiontree)
# Out:
# 5215265016.198241

# %%
mean_absolute_error(y_test,y_pred_decisiontree)
# Out:
# 49698.608254397834

# %% [markdown]
# Grafico el arbol

# %%
print(tree.export_text(arbol,
                      feature_names=["year", "engine_capacity_cc", "horsepower_hp"]))
# Out:
# |--- year <= 2017.50
# |   |--- horsepower_hp <= 250.00
# |   |   |--- year <= 2015.50
# |   |   |   |--- class: 29000
# |   |   |--- year >  2015.50
# |   |   |   |--- class: 55000
# |   |--- horsepower_hp >  250.00
# |   |   |--- year <= 2014.50
# |   |   |   |--- class: 69000
# |   |   |--- year >  2014.50
# |   |   |   |--- class: 65000
# |--- year >  2017.50
# |   |--- horsepower_hp <= 150.00
# |   |   |--- year <= 2020.50
# |   |   |   |--- class: 58000
# |   |   |--- year >  2020.50
# |   |   |   |--- class: 115000
# |   |--- horsepower_hp >  150.00
# |   |   |--- year <= 2020.50
# |   |   |   |--- class: 125000
# |   |   |--- year >  2020.50
# |   |   |   |--- class: 135000

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

bosque = RandomForestRegressor(n_estimators=100,
                               max_features="sqrt",
                               bootstrap=True,
                               max_samples=2/3,
                               oob_score=True)

bosque.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_features='sqrt', max_samples=0.6666666666666666,
#                       oob_score=True)

# %% [markdown]
# Generacion de la prediccion

# %%
y_pred_randomforest = bosque.predict(x_test)

# %% [markdown]
# Evaluacion del modelo

# %%
r2_score(y_test, y_pred_randomforest)
# Out:
# 0.6155574141134088

# %%
mean_squared_error(y_test,y_pred_randomforest , squared=False)
# Out:
# 52636.77737323035

# %%
mean_squared_error(y_test,y_pred_randomforest)
# Out:
# 2770630332.239014

# %%
mean_absolute_error(y_test,y_pred_randomforest)
# Out:
# 35387.89251017149

# %% [markdown]
# KNN

# %%
from sklearn import preprocessing
escala_x = preprocessing.MinMaxScaler()
escala_y = preprocessing.MinMaxScaler()

x_escalado = escala_x.fit_transform(x)
y_escalado = escala_y.fit_transform(y.values.reshape(-1,1))

# %%
x_escalado
# Out:
# array([[0.94915254, 1.        , 0.66666667],
#        [0.91525424, 0.5       , 0.33333333],
#        [0.94915254, 0.375     , 0.33333333],
#        ...,
#        [0.93220339, 0.375     , 0.        ],
#        [0.83050847, 0.875     , 0.33333333],
#        [0.86440678, 0.375     , 0.        ]])

# %%
y_escalado
# Out:
# array([[0.3229728 ],
#        [0.3731044 ],
#        [0.19764382],
#        ...,
#        [0.07757864],
#        [0.13522998],
#        [0.05251285]])

# %% [markdown]
# Separacion de las variables en entrenamiento y prueba

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_escalado,y_escalado)

# %% [markdown]
# Creacion del modelo

# %%
from sklearn.neighbors import KNeighborsRegressor

knn=KNeighborsRegressor(n_neighbors=3)

knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %% [markdown]
# Prediccion de los datos de prueba

# %%
y_pred_knnregressor = knn.predict(x_test)

# %% [markdown]
# Evaluacion del modelo

# %%
r2_score(y_test, y_pred_knnregressor)
# Out:
# 0.4740810724918054

# %%
mean_squared_error(y_test,y_pred_decisiontree , squared=False)
# Out:
# 99220.80649294266

# %%
mean_squared_error(y_test,y_pred_decisiontree)
# Out:
# 9844768441.109974

# %%
mean_absolute_error(y_test,y_pred_decisiontree)
# Out:
# 91065.3496201073

# %% [markdown]
# Analisis con GridSearchCV

# %% [markdown]
# Defino el diccionario para luego analizar los distintos modelos y los distintos hiperparametros

# %%
model_params = {
    'linear_regression':{
        'model':linear_model.LinearRegression(),
        'params':{}
    },

    'random_forest':{
        'model':RandomForestRegressor(max_features="sqrt",
                               bootstrap=True,
                               max_samples=2/3,
                               oob_score=True),
        'params':{
            'n_estimators':[100,125,150],
            'criterion':['squared_error','absolute_error', 'poisson']
        }
    },
    'knn':{
        'model':KNeighborsRegressor(),
        'params':{
            'n_neighbors':np.arange(3,8,1)
        }
    }
}

# %% [markdown]
# Hago un for para hacer la comparacion

# %%
from sklearn.model_selection import GridSearchCV

scores = []

for model_name, mp in model_params.items():
    clf = GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(x_train,y_train)
    scores.append({
        'model':model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %% [markdown]
# Imprimo los resultados: el mejor modelo es el de Random Forest con cirterio de squared_error y n_estimators=100

# %%
scores
# Out:
# [{'model': 'linear_regression',
#   'best_score': 0.43210366032290015,
#   'best_params': {}},
#  {'model': 'random_forest',
#   'best_score': 0.6190614522915381,
#   'best_params': {'criterion': 'squared_error', 'n_estimators': 150}},
#  {'model': 'knn',
#   'best_score': 0.5961035939438031,
#   'best_params': {'n_neighbors': 7}}]

# %%
df_scores = pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
df_scores
# Out:
#                model  best_score  \
# 0  linear_regression    0.432104
# 1      random_forest    0.619061
# 2                knn    0.596104
#
#                                          best_params
# 0                                                 {}
# 1  {'criterion': 'squared_error', 'n_estimators':...
# 2                                 {'n_neighbors': 7}

# %% [markdown]
# # **Conclusiones Finales**

# %% [markdown]
# Se decidio en primera instancia analizar 4 modelos con distintos resultados cada uno:
#
# Regresion lineal dio un R2 de 0.37276936371405556
#
# Arbol de decision dio un R2 de 0.2763487984732841
#
# Random Forest dio un R2 de 0.6155574141134088
#
# KNN dio un R2 de 0.4740810724918054
#
# De esto se puede concluir que el Random Forest es el mejor de estos modelos.

# %% [markdown]
# Luego, se decidio analizar los modelos de regresion linear, random forest y knn teniendo en cuenta distintos parametros de cada uno de los modelos para ver comparativamente cual era el mejor y cual era la mejor combinacion de parametros
#
# Los distintos parametros que se analizaron fueron:
#
# -Random Forest: n_estimators:100,125 y 150. Criterion:'squared_error','absolute_error', 'poisson'
#
# -KNN: n_neighbors: 3,4,5,6,7
#
# Se concluyo que el mejor modelo era el Random Forest con 150 arboles y el criterio squared_error. Su R2 fue 0.6190614522915381
#
# Tambien, se observo que el modelo knn mejora mucho con n_neighbors=7
